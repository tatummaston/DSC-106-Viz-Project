# %%
import pandas as pd

# %%
df = pd.read_csv("ad_viz_plotval_data-3.csv")

# %%
df["Site Name"].unique()
# Out:
# array(['Azusa', 'Glendora', 'Los Angeles-North Main Street', 'Reseda',
#        'Compton', 'Pico Rivera #2', 'Pasadena', 'Long Beach (North)',
#        'Long Beach (South)', 'Long Beach-Route 710 Near Road',
#        'North Hollywood (NOHO)', 'Santa Clarita',
#        'Lancaster-Division Street', 'Lebec', 'Anaheim', 'Mission Viejo'],
#       dtype=object)

# %%
df = df[df["Site Name"] == 'Los Angeles-North Main Street']

# %%
pd.set_option('display.max_rows', None)

# %%
indiv = df.sort_values(by=['Date'])[df['POC'] == 9]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
indiv = indiv[(indiv['Date']< '04/01/2020')]
indiv = indiv[(indiv['Date']>'01/20/2020')]
indiv
# Out:
#            Date Source   Site ID  POC  Daily Mean PM2.5 Concentration  \
# 637  01/21/2020    AQS  60371103    9                             9.7
# 638  01/22/2020    AQS  60371103    9                            12.5
# 639  01/23/2020    AQS  60371103    9                            12.7
# 640  01/24/2020    AQS  60371103    9                            14.2
# 641  01/25/2020    AQS  60371103    9                            29.0
# 642  01/26/2020    AQS  60371103    9                            38.2
# 643  01/27/2020    AQS  60371103    9                            21.2
# 644  01/28/2020    AQS  60371103    9                             8.2
# 645  01/29/2020    AQS  60371103    9                             8.2
# 646  01/30/2020    AQS  60371103    9                             9.0
# 647  01/31/2020    AQS  60371103    9                            10.0
# 648  02/01/2020    AQS  60371103    9                             8.3
# ...

# %%
import matplotlib.pyplot as plt

# %%
indiv.plot.scatter(x='Date', y='DAILY_AQI_VALUE')

# %%
indiv[['Date','DAILY_AQI_VALUE']]
# Out:
#            Date  DAILY_AQI_VALUE
# 637  01/21/2020               40
# 638  01/22/2020               52
# 639  01/23/2020               52
# 640  01/24/2020               55
# 641  01/25/2020               87
# 642  01/26/2020              108
# 643  01/27/2020               70
# 644  01/28/2020               34
# 645  01/29/2020               34
# 646  01/30/2020               38
# 647  01/31/2020               42
# 648  02/01/2020               35
# 649  02/02/2020               50
# 650  02/03/2020               15
# 651  02/04/2020               31
# 652  02/05/2020               26
# 653  02/06/2020               48
# 654  02/07/2020               59
# 655  02/08/2020               71
# 656  02/09/2020               51
# 657  02/10/2020               35
# 658  02/11/2020               36
# 659  02/12/2020               48
# 660  02/13/2020               58
# 661  02/14/2020               64
# 662  02/15/2020               65
# 663  02/16/2020               64
# ...

# %%
year = [] 
for i in range(1878,2019):
    year.append(i)

# %%
temp = [61.9,59.8,62.4,62.3,62.8,62,62.5,62.4,63.1,63.6,63,61.6,61.5,60.3,61.7,63.1,61.8,62.7,61.9,63.5,62.1,61.2,62.2,63.9,62.6,65,63.3,61.9,61.4,63.1,62.1,62.7,62.5,63.6,63,60.9,63,63.9,62.9,62.4,63,62.5,63.7,63.5,63.9,65.1,63.3,64.2,64.2,64.6,64.9,66.5,63.6,62.4,65.8,63.6,65.2,63.5,64.6,65.4,65,64,63.5,64.2,62.2,63.1,63.2,64.1,62.9,63.4,63.8,63.5,63.6,64.6,64.9,63.7,64.7,65.7,67,67.3,65.6,65.3,63.2,65.1,63.6,64.3,66,66.4,66.2,65.4,66.1,65.1,66.5,65,65.3,63,65.2,65.9,65.5,65.4,67.7,68.9,65.5,68.9,68.4,67,67.7,66,66.1,66.6,67.5,65.8,68,67.2,67.5,67.8,67.6,68.3,66.1,64.2,65.1,64.0,64.4,65.4,65.4,65.2,66.7,65.6,66.4,66.2,65.7,63.9,65.5,65.6,68,1,68.3,76.1,68.26,67.2,66.1]

# %%
len(temp)
# Out:
# 141

# %%
plt.scatter(year,temp)

# %% [markdown]
# nitrous oxide - 7
# methane 10
# fluorinated gases 3
# carbon dioxide 81

# %%
import datetime
import time

# %%
date_time_obj = datetime.date.strp("01/01/2020", '%d/%m/%y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c96c64b12311> in <module>
# ----> 1 date_time_obj = datetime.date.strp("01/01/2020", '%d/%m/%y')
#
# AttributeError: type object 'datetime.date' has no attribute 'strp'

# %%
time.mktime(datetime.date(2020,1,1).timetuple())
# Out:
# 1577865600.0

# %%
aqis = indiv['DAILY_AQI_VALUE'].tolist()

# %%
dates = indiv['Date'].tolist()

# %%
seconds = []
for i in dates: 
    mon = int(i[0:2])
    day = int(i[3:5])
    yr = int(i[6:10])
    seconds.append(time.mktime(datetime.date(yr,mon,day).timetuple()))

# %%
json = ""
j=0
for i in seconds:
    json = json+"\""+str(i)+"\":"+str(aqis[j])+","
    j+=1

# %%
json
# Out:
# '"1579593600.0":40,"1579680000.0":52,"1579766400.0":52,"1579852800.0":55,"1579939200.0":87,"1580025600.0":108,"1580112000.0":70,"1580198400.0":34,"1580284800.0":34,"1580371200.0":38,"1580457600.0":42,"1580544000.0":35,"1580630400.0":50,"1580716800.0":15,"1580803200.0":31,"1580889600.0":26,"1580976000.0":48,"1581062400.0":59,"1581148800.0":71,"1581235200.0":51,"1581321600.0":35,"1581408000.0":36,"1581494400.0":48,"1581580800.0":58,"1581667200.0":64,"1581753600.0":65,"1581840000.0":64,"1581926400.0":70,"1582012800.0":72,"1582099200.0":80,"1582185600.0":66,"1582272000.0":49,"1582358400.0":31,"1582444800.0":43,"1582531200.0":59,"1582617600.0":53,"1582704000.0":43,"1582790400.0":35,"1582876800.0":28,"1582963200.0":47,"1583049600.0":37,"1583136000.0":25,"1583222400.0":34,"1583308800.0":59,"1583395200.0":65,"1583481600.0":64,"1583568000.0":24,"1583654400.0":18,"1583737200.0":25,"1583823600.0":23,"1583910000.0":25,"1583996400.0":35,"1584082800.0":30,"1584169200.0":30,"1584255600.0":21,"15843
# ...
